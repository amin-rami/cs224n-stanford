# %%
# !git init
# !git remote add origin https://github.com/amin-rami/nlp-with-deep-learning-stanford.git
# !git fetch
# !git checkout main
# !git pull
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/
# remote: Enumerating objects: 270, done.
# remote: Counting objects: 100% (270/270), done.
# remote: Compressing objects: 100% (152/152), done.
# remote: Total 270 (delta 123), reused 258 (delta 114), pack-reused 0 (from 0)
# Receiving objects: 100% (270/270), 3.33 MiB | 6.64 MiB/s, done.
# Resolving deltas: 100% (123/123), done.
# From https://github.com/amin-rami/nlp-with-deep-learning-stanford
# ...

# %%
# !pip install -r ./assignments/assignment4/gpu_requirements.txt

# %%
# !mv ./assignments/assignment4/* .

# %%
# !sh run.sh train
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cuda:0
# begin Maximum Likelihood training
# epoch 1, iter 10, avg. loss 210.65, avg. ppl 3639.21 cum. examples 320, speed 2971.52 words/sec, time elapsed 2.77 sec
# epoch 1, iter 20, avg. loss 178.15, avg. ppl 773.81 cum. examples 640, speed 7684.68 words/sec, time elapsed 3.88 sec
# epoch 1, iter 30, avg. loss 165.84, avg. ppl 562.36 cum. examples 960, speed 6982.47 words/sec, time elapsed 5.08 sec
# epoch 1, iter 40, avg. loss 170.62, avg. ppl 476.13 cum. examples 1280, speed 7400.40 words/sec, time elapsed 6.28 sec
# epoch 1, iter 50, avg. loss 161.83, avg. ppl 367.05 cum. examples 1600, speed 7917.81 words/sec, time elapsed 7.39 sec
# epoch 1, iter 60, avg. loss 153.43, avg. ppl 343.83 cum. examples 1920, speed 7863.64 words/sec, time elapsed 8.46 sec
# ...

# %%
# !sh run.sh test
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# load test source sentences from [./chr_en_data/test.chr]
# load test target sentences from [./chr_en_data/test.en]
# load model from model.bin
# ...
